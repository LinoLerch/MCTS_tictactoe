# %%
import gymnasium
import gym_examples
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=UserWarning)
from gridworld_demo import gridworld_demo

# %% [markdown]
# ### GridWorld Demo MCTS

# %%
gridworld_demo(ipynb=True)
# Out:
# <PIL.Image.Image image mode=RGB size=150x150>
# MCTS Iteration 500/500
# Target: [0 2]
#   agent: [2 2], visits: 500, value: 0.15
#     ← agent: [1 2], visits: 134, value: 0.17
#     ↓ agent: [2 3], visits: 126, value: 0.17
#     ↑ agent: [2 1], visits: 112, value: 0.15
#     → agent: [3 2], visits: 128, value: 0.17
# Selected action: ←
# Obs: {'agent': array([1, 2]), 'target': array([0, 2])}
# <PIL.Image.Image image mode=RGB size=150x150>
# MCTS Iteration 500/500
# Target: [0 2]
#  ← agent: [1 2], visits: 634, value: 0.22
#     ↓ agent: [2 3], visits: 124, value: 0.2
#     ↑ agent: [2 1], visits: 196, value: 0.27
#     → agent: [3 2], visits: 145, value: 0.22
#     ← agent: [1 2], visits: 168, value: 0.25
# Selected action: ↑
# Obs: {'agent': array([1, 1]), 'target': array([0, 2])}
# <PIL.Image.Image image mode=RGB size=150x150>
# MCTS Iteration 500/500
# Target: [0 2]
#  ↑ agent: [2 1], visits: 696, value: 0.22
#     ↓ agent: [2 3], visits: 195, value: 0.26
# ...
